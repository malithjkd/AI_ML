# %%
import pandas as pd

# %%
df = pd.read_csv('/home/malitjkd/Documents/Codes/AI_ML/Self_Learn/datasets/Insurance_Data.csv')

# %%
df
# Out:
#        Policy Number  Number of Vehicles  Average Age  Gender Dummy  \
# 0             150023                   1         20.6             1
# 1             152720                   1         42.4             0
# 2             174207                   1         42.4             1
# 3             139895                   1         42.4             0
# 4             174407                   1         20.6             1
# ...              ...                 ...          ...           ...
# 15285         189499                   4         65.1             0
# 15286         142111                   4         65.1             0
# 15287         175986                   4         65.1             0
# 15288         199800                   4         20.6             1
# 15289         187711                   4         20.6             0
#
#        Married Dummy  Avg Veh Age  Fuel Type Dummy      Losses
# 0                  0        12.97                0  203.319595
# ...

# %%
df_dis = df.describe()
print(df_dis)
# Out:
#        Policy Number  Number of Vehicles   Average Age  Gender Dummy  \
# count   15290.000000        15290.000000  15290.000000  15290.000000
# mean   149910.276651            2.495880     42.341969      0.493329
# std     28948.806631            0.953776     16.976615      0.499972
# min    100002.000000            1.000000     20.600000      0.000000
# 25%    124842.000000            2.000000     20.600000      0.000000
# 50%    149872.000000            2.000000     42.400000      0.000000
# 75%    175011.000000            3.000000     65.100000      1.000000
# max    200000.000000            4.000000     65.100000      1.000000
#
#        Married Dummy   Avg Veh Age  Fuel Type Dummy        Losses
# count   15290.000000  15290.000000     15290.000000  15290.000000
# mean        0.490974      8.656579         0.236756    389.859718
# std         0.499935      4.084988         0.425105    253.729433
# min         0.000000      2.500000         0.000000     12.534521
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15290 entries, 0 to 15289
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Policy Number       15290 non-null  int64
#  1   Number of Vehicles  15290 non-null  int64
#  2   Average Age         15290 non-null  float64
#  3   Gender Dummy        15290 non-null  int64
#  4   Married Dummy       15290 non-null  int64
#  5   Avg Veh Age         15290 non-null  float64
#  6   Fuel Type Dummy     15290 non-null  int64
#  7   Losses              15290 non-null  float64
# dtypes: float64(3), int64(5)
# memory usage: 955.8 KB

# %%
df['Number of Vehicles'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
print(df.iloc[:,1])
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 15285    4
# 15286    4
# 15287    4
# 15288    4
# 15289    4
# Name: Number of Vehicles, Length: 15290, dtype: int64

# %%
print(df.iloc[:,0])
# Out:
# 0        150023
# 1        152720
# 2        174207
# 3        139895
# 4        174407
#           ...
# 15285    189499
# 15286    142111
# 15287    175986
# 15288    199800
# 15289    187711
# Name: Policy Number, Length: 15290, dtype: int64

# %%
df.head()
# Out:
#    Policy Number  Number of Vehicles  Average Age  Gender Dummy  \
# 0         150023                   1         20.6             1
# 1         152720                   1         42.4             0
# 2         174207                   1         42.4             1
# 3         139895                   1         42.4             0
# 4         174407                   1         20.6             1
#
#    Married Dummy  Avg Veh Age  Fuel Type Dummy      Losses
# 0              0        12.97                0  203.319595
# 1              1         8.02                0  402.197302
# 2              0         2.50                1  553.132096
# 3              0        12.97                0  292.430579
# 4              1        12.97                0  246.540576

# %%
df_query = df.query('Losses > 300')
df_query.describe()
# Out:
#        Policy Number  Number of Vehicles  Average Age  Gender Dummy  \
# count    9630.000000         9630.000000  9630.000000   9630.000000
# mean   150019.802388            2.497092    36.904424      0.536241
# std     28954.770077            0.952906    13.954511      0.498711
# min    100015.000000            1.000000    20.600000      0.000000
# 25%    125089.750000            2.000000    20.600000      0.000000
# 50%    149897.500000            2.000000    42.400000      1.000000
# 75%    175135.250000            3.000000    42.400000      1.000000
# max    200000.000000            4.000000    65.100000      1.000000
#
#        Married Dummy  Avg Veh Age  Fuel Type Dummy       Losses
# count    9630.000000  9630.000000      9630.000000  9630.000000
# mean        0.558255     7.765813         0.375909   515.254434
# std         0.496620     4.033514         0.484382   236.594699
# min         0.000000     2.500000         0.000000   300.084962
# ...

# %%
df_sorted = df.sort_values(by='Losses')
df_sorted
# Out:
#        Policy Number  Number of Vehicles  Average Age  Gender Dummy  \
# 11180         132732                   3         65.1             0
# 13657         168897                   4         65.1             1
# 14931         168101                   4         65.1             0
# 3352          190567                   2         65.1             0
# 13514         177232                   4         65.1             0
# ...              ...                 ...          ...           ...
# 110           140879                   1         42.4             1
# 12706         132910                   3         20.6             1
# 7240          190026                   2         20.6             1
# 109           103178                   1         42.4             0
# 101           147315                   1         20.6             1
#
#        Married Dummy  Avg Veh Age  Fuel Type Dummy       Losses
# 11180              0        12.97                0    12.534521
# ...

# %%
df_sorted_af = df.sort_values(by='Losses',ascending=False)
df_sorted_af
# Out:
#        Policy Number  Number of Vehicles  Average Age  Gender Dummy  \
# 101           147315                   1         20.6             1
# 109           103178                   1         42.4             0
# 7240          190026                   2         20.6             1
# 12706         132910                   3         20.6             1
# 110           140879                   1         42.4             1
# ...              ...                 ...          ...           ...
# 13514         177232                   4         65.1             0
# 3352          190567                   2         65.1             0
# 14931         168101                   4         65.1             0
# 13657         168897                   4         65.1             1
# 11180         132732                   3         65.1             0
#
#        Married Dummy  Avg Veh Age  Fuel Type Dummy       Losses
# 101                1         2.50                1  3500.000000
# ...
